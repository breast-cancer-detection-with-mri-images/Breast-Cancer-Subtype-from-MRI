# %% [markdown]
# # Preliminary ML Model Results (with Feature Scaling)

# %%
import pandas as pd
import numpy as np
import xgboost
import seaborn as sns

import matplotlib.pyplot as plt

import plotly

# %% [markdown]
# ## Labels
#
# - ER:
#   - 0 = neg
#   - 1 = pos
# - PR:
#   - 0 = neg
#   - 1 = pos
# - HER2:
#   - 0 = neg
#   - 1 = pos
#   - 2 = borderline
# - Mol Subtype:
#   - 0 = luminal-like
#   - 1 = ER/PR pos, HER2 pos
#   - 2 = HER2
#   - 3 = triple negative

# %%
labels = pd.read_csv('Patient class labels.csv')
labels.head()
# Out:
#        Patient ID  ER  PR  HER2  Mol Subtype
# 0  Breast_MRI_001   0   0     1            2
# 1  Breast_MRI_002   0   0     0            3
# 2  Breast_MRI_003   1   1     0            0
# 3  Breast_MRI_004   1   1     0            0
# 4  Breast_MRI_005   1   0     1            1

# %%
features = pd.read_csv('pyradiomics_extraction.csv')
features.head()
# Out:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.891808                 0.850437
# 1                   0.891808                 0.850437
# 2                   0.668996                 0.650923
# 3                   0.668996                 0.650923
# 4                   0.934408                 0.286810
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                       29.186299                       34.319179
# 1                       29.186299                       34.319179
# 2                       18.931009                       29.083312
# 3                       18.931009                       29.083312
# 4                       13.808210                       48.144081
#
#    original_shape_Maximum2DDiameterColumn  \
# 0                               36.073737
# 1                               36.073737
# 2                               23.148662
# 3                               23.148662
# 4                               40.488107
#
#    original_shape_Maximum2DDiameterRow  original_shape_Maximum2DDiameterSlice  \
# 0                            38.431136                              39.309346
# 1                            38.431136                              39.309346
# 2                            29.852205                              29.748492
# 3                            29.852205                              29.748492
# 4                            43.126056                              56.606869
#
#    original_shape_Maximum3DDiameter  original_shape_MeshVolume  \
# 0                         46.240422               19914.791496
# 1                         46.240422               19914.791496
# 2                         33.784677                6966.458183
# 3                         33.784677                6966.458183
# 4                         57.665740               19467.935987
#
#    original_shape_MinorAxisLength  ...  original_glszm_ZoneEntropy  \
# 0                       30.606121  ...                    2.825564
# 1                       30.606121  ...                    2.580368
# 2                       19.456628  ...                    3.147323
# 3                       19.456628  ...                    3.339987
# 4                       44.986213  ...                    2.909565
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                       0.003846                 4.996251e+06
# 1                       0.004380                 4.745944e+06
# 2                       0.002108                 5.759789e+06
# 3                       0.003194                 4.028316e+06
# 4                       0.005536                 6.875739e+06
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0              1060.390698                   0.000323
# 1               714.483384                   0.000444
# 2               302.684948                   0.000982
# 3               253.258853                   0.001130
# 4               356.064866                   0.000750
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  \
# 0                   0.220287                 0.032468
# 1                   0.160234                 0.019571
# 2                   0.130170                 0.012262
# 3                   0.113070                 0.008739
# 4                   0.063894                 0.002623
#
#    original_ngtdm_Strength         patient  sequence
# 0                 0.000324  Breast_MRI_001       pre
# 1                 0.000443  Breast_MRI_001    post_1
# 2                 0.000985  Breast_MRI_002       pre
# 3                 0.001129  Breast_MRI_002    post_1
# 4                 0.000748  Breast_MRI_003       pre
#
# [5 rows x 109 columns]

# %%
pre_features = features[features['sequence'] == 'pre']
total_features = pd.merge(pre_features, labels, left_on = 'patient', right_on = 'Patient ID').drop(columns = 'Patient ID')

# %%
total_features
# Out:
#      original_shape_Elongation  original_shape_Flatness  \
# 0                     0.891808                 0.850437
# 1                     0.668996                 0.650923
# 2                     0.934408                 0.286810
# 3                     0.707826                 0.609522
# 4                     0.679296                 0.424353
# ..                         ...                      ...
# 917                   0.877153                 0.648783
# 918                   0.964239                 0.648439
# 919                   0.877183                 0.856791
# 920                   0.913000                 0.800835
# 921                   0.945533                 0.798995
#
#      original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                         29.186299                       34.319179
# 1                         18.931009                       29.083312
# 2                         13.808210                       48.144081
# 3                          8.893590                       14.591090
# 4                         22.534695                       53.103672
# ..                              ...                             ...
# 917                       29.186299                       44.986213
# 918                       13.914028                       21.457727
# 919                       15.749673                       18.382163
# 920                       33.226543                       41.489900
# 921                        9.708553                       12.150957
#
#      original_shape_Maximum2DDiameterColumn  \
# 0                                 36.073737
# 1                                 23.148662
# 2                                 40.488107
# 3                                 11.420813
# 4                                 55.175581
# ..                                      ...
# 917                               45.886501
# 918                               21.631462
# 919                               19.038279
# 920                               43.076382
# 921                               14.031840
#
#      original_shape_Maximum2DDiameterRow  \
# 0                              38.431136
# 1                              29.852205
# 2                              43.126056
# 3                              14.972284
# 4                              49.674566
# ..                                   ...
# 917                            41.977361
# 918                            21.084250
# 919                            20.649190
# 920                            45.448460
# 921                            12.641847
#
#      original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 0                                39.309346                         46.240422
# 1                                29.748492                         33.784677
# 2                                56.606869                         57.665740
# 3                                14.477716                         16.540987
# 4                                36.443449                         58.274413
# ..                                     ...                               ...
# 917                              51.383808                         56.811793
# 918                              25.375225                         27.677709
# 919                              20.505122                         24.348411
# 920                              48.143552                         55.603011
# 921                              13.078416                         16.022136
#
#      original_shape_MeshVolume  original_shape_MinorAxisLength  ...  \
# 0                 19914.791496                       30.606121  ...
# 1                  6966.458183                       19.456628  ...
# 2                 19467.935987                       44.986213  ...
# 3                   871.867992                       10.327956  ...
# 4                 28042.704264                       36.073114  ...
# ..                         ...                             ...  ...
# 917               33662.244229                       39.459771  ...
# 918                4018.670942                       20.690383  ...
# 919                3033.167788                       16.124515  ...
# 920               33924.801358                       37.880295  ...
# 921                 881.013461                       11.489125  ...
#
#      original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# 0                     0.000323                   0.220287
# 1                     0.000982                   0.130170
# 2                     0.000750                   0.063894
# 3                     0.768596                   0.001460
# 4                     0.008849                   0.004913
# ..                         ...                        ...
# 917                   0.001344                   0.022699
# 918                   0.015225                   0.015796
# 919                   0.133894                   0.002823
# 920                   0.001018                   0.042386
# 921                   0.073097                   0.015201
#
#      original_ngtdm_Contrast  original_ngtdm_Strength         patient  \
# 0                   0.032468                 0.000324  Breast_MRI_001
# 1                   0.012262                 0.000985  Breast_MRI_002
# 2                   0.002623                 0.000748  Breast_MRI_003
# 3                   0.000002                 0.606008  Breast_MRI_004
# 4                   0.000023                 0.008499  Breast_MRI_005
# ..                       ...                      ...             ...
# 917                 0.000827                 0.001322  Breast_MRI_918
# 918                 0.000151                 0.014937  Breast_MRI_919
# 919                 0.000004                 0.132276  Breast_MRI_920
# 920                 0.001378                 0.001013  Breast_MRI_921
# 921                 0.000122                 0.075003  Breast_MRI_922
#
#      sequence  ER  PR  HER2  Mol Subtype
# 0         pre   0   0     1            2
# 1         pre   0   0     0            3
# 2         pre   1   1     0            0
# 3         pre   1   1     0            0
# 4         pre   1   0     1            1
# ..        ...  ..  ..   ...          ...
# 917       pre   1   1     0            0
# 918       pre   1   1     0            0
# 919       pre   1   1     0            0
# 920       pre   1   1     0            0
# 921       pre   1   1     0            0
#
# [922 rows x 113 columns]

# %% [markdown]
# ## Data Processing and Feature Selection: TODO

# %% [markdown]
# # Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report, f1_score, roc_auc_score

from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

# %%
TRAIN_RATIO = 0.6
VAL_RATIO = 0.2
TEST_RATIO = 0.2

SEED = 2454259

# %%
def train_test_val_splits(df, train_ratio = 0.8, val_ratio = 0.2, random_state = 2454259):
   
    val_ratio_adj = val_ratio / (1-train_ratio)

    train_df, val_df = train_test_split(df, train_size = train_ratio, random_state= random_state)
    val_df, test_df = train_test_split(val_df, train_size = val_ratio_adj, random_state= random_state)

    print(len(train_df))

    return train_df, val_df, test_df

# %%
train_df, val_df, test_df = train_test_val_splits(total_features.drop(columns = ['sequence', 'patient']), TRAIN_RATIO, VAL_RATIO, random_state = SEED)
len(train_df), len(val_df), len(test_df)
# Out:
# 553
# (553, 184, 185)

# %%
train_x, train_y_er, train_y_pr, train_y_her, train_y_mol_subtype = train_df.drop(columns = ['ER', 'PR', 'HER2', 'Mol Subtype']), train_df['ER'], train_df['PR'], train_df['HER2'], train_df['Mol Subtype']
val_x, val_y_er, val_y_pr, val_y_her, val_y_mol_subtype = val_df.drop(columns = ['ER', 'PR', 'HER2', 'Mol Subtype']), val_df['ER'], val_df['PR'], val_df['HER2'], val_df['Mol Subtype']
test_x, test_y_er, test_y_pr, test_y_her, test_y_mol_subtype = test_df.drop(columns = ['ER', 'PR', 'HER2', 'Mol Subtype']), test_df['ER'], test_df['PR'], test_df['HER2'], test_df['Mol Subtype']

# %% [markdown]
# ### Class distribution in the train, val and test splits

# %%
print("Train ER neg: {}, pos: {}\nVal ER neg: {}, pos: {}\nTest ER neg: {}, pos: {}".format(train_y_er.value_counts()[0], train_y_er.value_counts()[1],
                                                                                           val_y_er.value_counts()[0]    , val_y_er.value_counts()[1],
                                                                                           test_y_er.value_counts()[0]   , test_y_er.value_counts()[1])
)
# Out:
# Train ER neg: 139, pos: 414
# Val ER neg: 46, pos: 138
# Test ER neg: 51, pos: 134

# %%
print("Train PR neg: {}, pos: {}\nVal PR neg: {}, pos: {}\nTest PR neg: {}, pos: {}".format(train_y_pr.value_counts()[0]  , train_y_pr.value_counts()[1],
                                                                                           val_y_pr.value_counts()[0]    , val_y_pr.value_counts()[1],
                                                                                           test_y_pr.value_counts()[0]   , test_y_pr.value_counts()[1])
)
# Out:
# Train PR neg: 194, pos: 359
# Val PR neg: 66, pos: 118
# Test PR neg: 64, pos: 121

# %%
print("Train HER neg: {}, pos: {}\nVal HER neg: {}, pos: {}\nTest HER neg: {}, pos: {}".format(
                                                                                           train_y_her.value_counts()[0]  , train_y_her.value_counts()[1],
                                                                                           val_y_her.value_counts()[0]    , val_y_her.value_counts()[1],
                                                                                           test_y_her.value_counts()[0]   , test_y_her.value_counts()[1])
)
# Out:
# Train HER neg: 452, pos: 101
# Val HER neg: 153, pos: 31
# Test HER neg: 154, pos: 31

# %%
def train_pipeline(model, trainx, trainy, valx, valy):
    model.fit(trainx, trainy)
    preds = model.predict(trainx)
    preds_val = model.predict(valx)

    acc_train, acc_val = accuracy_score(trainy, preds), accuracy_score(valy, preds_val)
    prec_train, prec_val = precision_score(trainy, preds, average = 'weighted'), precision_score(valy, preds_val, average = 'weighted')
    rec_train, rec_val = recall_score(trainy, preds, average = 'weighted'), recall_score(valy, preds_val, average = 'weighted')
    f1_train, f1_val = f1_score(trainy, preds, average = 'weighted'), f1_score(valy, preds_val, average = 'weighted')

    metrics = {'train_acc' : acc_train, 'val_acc' : acc_val,
               'train_prec': prec_train, 'val_prec': prec_val,
               'train_rec' : rec_train,  'val_rec' : rec_val,
               'train_f1' : f1_train, 'val_f1': f1_val}


    print("Training Accuracy: {:.4f}, Validation Accuracy: {:.4f}".format(acc_train, acc_val))
    print("Training Precision: {:.4f}, Validation Precision: {:.4f}".format(prec_train, prec_val))
    print("Training Recall: {:.4f}, Validation Recall: {:.4f}".format(rec_train, rec_val))
    print("Training F1-Score: {:.4f}, Validation F1-Score: {:.4f}".format(f1_train, f1_val))

    return model, metrics

# %%
def get_classification_report(model, trainx, trainy, valx, valy, testx, testy, class_names, title, subtype = None):
    model, metrics = train_pipeline(model, trainx, trainy, valx, valy)
    pred = model.predict(testx)


    acc_test = accuracy_score(testy, pred)
    prec_test = precision_score(testy, pred, average = 'weighted')
    rec_test = recall_score(testy, pred, average = 'weighted')
    f1_test = f1_score(testy, pred, average = 'weighted')
    
    metrics.update(
            {'test_acc' : acc_test,
            'test_prec': prec_test,
            'test_rec' : rec_test,
            'test_f1' : f1_test})

    if len(trainy.unique()) == 2 and not isinstance(model, SVC):
        probs = model.predict_proba(test_x)
        aucroc = roc_auc_score(testy, probs[:, 1], average = 'weighted')
        metrics.update({'test_aucroc' : aucroc})

    cls_report = classification_report(testy, pred, target_names = class_names, output_dict = True)
    sns.heatmap(pd.DataFrame(cls_report).iloc[:-1, :].T, annot=True)
    plt.title(title)
    return metrics, model

# %% [markdown]
# ## Classifications

# %%
classification_results = pd.DataFrame()

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler as Scaler

# %%
scaler = Scaler()
scaler.fit(train_x)
# Out:
# MinMaxScaler()

# %%
train_x = scaler.transform(train_x)
val_x = scaler.transform(val_x)
test_x = scaler.transform(test_x)

# %% [markdown]
# ## Models

# %% [markdown]
# ### Naive Bayes

# %%
nb_er = GaussianNB()
report, nb_er = get_classification_report(nb_er, train_x, train_y_er, val_x, val_y_er, test_x, test_y_er, ['ER Negative', 'ER Positive'], 'ER Subtype metrics on testing set', subtype = 'ER')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Naive Bayes'
result['Subtype'] = 'ER'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.7125, Validation Accuracy: 0.7337
# Training Precision: 0.6797, Validation Precision: 0.6949
# Training Recall: 0.7125, Validation Recall: 0.7337
# Training F1-Score: 0.6909, Validation F1-Score: 0.7037

# %%
nb_pr = GaussianNB()
report, nb_pr = get_classification_report(nb_er, train_x, train_y_pr, val_x, val_y_pr, test_x, test_y_pr, ['PR Negative', 'PR Positive'], 'PR Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Naive Bayes'
result['Subtype'] = 'PR'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.6383, Validation Accuracy: 0.6467
# Training Precision: 0.6034, Validation Precision: 0.6149
# Training Recall: 0.6383, Validation Recall: 0.6467
# Training F1-Score: 0.6015, Validation F1-Score: 0.5977

# %%
nb_mol_subtype = GaussianNB()
report, nb_mol_subtype = get_classification_report(nb_mol_subtype, train_x, train_y_mol_subtype, val_x, val_y_mol_subtype, test_x, test_y_mol_subtype, ['Luminal', 'ER/PR pos, HER2 pos', 'HER2', 'Triple Negative'], 'Mol Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Naive Bayes'
result['Subtype'] = 'Mol Subtype'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.3580, Validation Accuracy: 0.3533
# Training Precision: 0.5907, Validation Precision: 0.6430
# Training Recall: 0.3580, Validation Recall: 0.3533
# Training F1-Score: 0.4008, Validation F1-Score: 0.4156

# %%
nb_her2 = GaussianNB()
report, nb_her2 = get_classification_report(nb_her2, train_x, train_y_her, val_x, val_y_her, test_x, test_y_her, ['HER2 Negative', 'HER2 Positive'], 'HER2 Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Naive Bayes'
result['Subtype'] = 'HER2'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.6890, Validation Accuracy: 0.7174
# Training Precision: 0.7176, Validation Precision: 0.7442
# Training Recall: 0.6890, Validation Recall: 0.7174
# Training F1-Score: 0.7021, Validation F1-Score: 0.7297

# %% [markdown]
# ### Logistic Regression

# %%
logreg_er = LogisticRegression()
report, logreg_er = get_classification_report(logreg_er, train_x, train_y_er, val_x, val_y_er, test_x, test_y_er, ['ER Negative', 'ER Positive'], 'ER Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Logistic Regression'
result['Subtype'] = 'ER'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.7613, Validation Accuracy: 0.7554
# Training Precision: 0.7440, Validation Precision: 0.7198
# Training Recall: 0.7613, Validation Recall: 0.7554
# Training F1-Score: 0.6858, Validation F1-Score: 0.6729
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
logreg_pr = LogisticRegression()
report, logreg_pr = get_classification_report(logreg_pr, train_x, train_y_pr, val_x, val_y_pr, test_x, test_y_pr, ['PR Negative', 'PR Positive'], 'PR Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Logistic Regression'
result['Subtype'] = 'PR'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])

classification_results
# Out:
# Training Accuracy: 0.6637, Validation Accuracy: 0.6467
# Training Precision: 0.6380, Validation Precision: 0.6125
# Training Recall: 0.6637, Validation Recall: 0.6467
# Training F1-Score: 0.5979, Validation F1-Score: 0.5669
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#              Algorithm      Subtype  train_acc   val_acc  train_prec  \
# 0          Naive Bayes           ER   0.712477  0.733696    0.679733
# 0          Naive Bayes           PR   0.638336  0.646739    0.603406
# 0          Naive Bayes  Mol Subtype   0.358047  0.353261    0.590729
# 0          Naive Bayes         HER2   0.688969  0.717391    0.717563
# 0  Logistic Regression           ER   0.761302  0.755435    0.743978
# 0  Logistic Regression           PR   0.663653  0.646739    0.638045
#
#    val_prec  train_rec   val_rec  train_f1    val_f1  test_acc  test_prec  \
# 0  0.694906   0.712477  0.733696  0.690949  0.703727  0.632432   0.586247
# 0  0.614888   0.638336  0.646739  0.601453  0.597718  0.589189   0.549599
# 0  0.643003   0.358047  0.353261  0.400832  0.415567  0.275676   0.445708
# 0  0.744239   0.688969  0.717391  0.702098  0.729747  0.718919   0.770203
# 0  0.719832   0.761302  0.755435  0.685765  0.672945  0.702703   0.567945
# 0  0.612516   0.663653  0.646739  0.597933  0.566915  0.654054   0.614359
#
#    test_rec   test_f1  test_aucroc
# 0  0.632432  0.604617     0.530875
# 0  0.589189  0.560321     0.526795
# 0  0.275676  0.310094          NaN
# 0  0.718919  0.740047     0.593842
# 0  0.702703  0.606720     0.570530
# 0  0.654054  0.595159     0.581870

# %%
logreg_her2 = LogisticRegression()
report, logreg_her2 = get_classification_report(logreg_her2, train_x, train_y_her, val_x, val_y_her, test_x, test_y_her, ['HER2 Negative', 'HER2 Positive'], 'HER2 Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Logistic Regression'
result['Subtype'] = 'HER2'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.8174, Validation Accuracy: 0.8207
# Training Precision: 0.7613, Validation Precision: 0.6899
# Training Recall: 0.8174, Validation Recall: 0.8207
# Training F1-Score: 0.7418, Validation F1-Score: 0.7496
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
logreg_mol_subtype = LogisticRegression()
report, logreg_mol_subtype = get_classification_report(logreg_mol_subtype, train_x, train_y_mol_subtype, val_x, val_y_mol_subtype, test_x, test_y_mol_subtype, ['Luminal', 'ER/PR pos, HER2 pos', 'HER2', 'Triple Negative'], 'Mol Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Logistic Regression'
result['Subtype'] = 'Mol Subtype'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.6582, Validation Accuracy: 0.6576
# Training Precision: 0.5486, Validation Precision: 0.5287
# Training Recall: 0.6582, Validation Recall: 0.6576
# Training F1-Score: 0.5404, Validation F1-Score: 0.5389
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Decision Tree

# %%
tree_er = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4)
report, tree_er = get_classification_report(tree_er, train_x, train_y_er, val_x, val_y_er, test_x, test_y_er, ['ER Negative', 'ER Positive'], 'ER Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Decision Tree'
result['Subtype'] = 'ER'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.7740, Validation Accuracy: 0.7228
# Training Precision: 0.7626, Validation Precision: 0.6170
# Training Recall: 0.7740, Validation Recall: 0.7228
# Training F1-Score: 0.7162, Validation F1-Score: 0.6460

# %%
tree_pr = DecisionTreeClassifier(criterion = 'gini', max_depth = 4)
report, tree_pr = get_classification_report(tree_pr, train_x, train_y_pr, val_x, val_y_pr, test_x, test_y_pr, ['PR Negative', 'PR Positive'], 'PR Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Decision Tree'
result['Subtype'] = 'PR'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.7360, Validation Accuracy: 0.6141
# Training Precision: 0.7354, Validation Precision: 0.6078
# Training Recall: 0.7360, Validation Recall: 0.6141
# Training F1-Score: 0.7357, Validation F1-Score: 0.6105

# %%
tree_her2 = DecisionTreeClassifier(criterion = 'gini', max_depth = 10, min_samples_split = 8)
report, tree_her2 = get_classification_report(tree_her2, train_x, train_y_her, val_x, val_y_her, test_x, test_y_her, ['HER2 Negative', 'HER2 Positive'], 'HER2 Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Decision Tree'
result['Subtype'] = 'HER2'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.8969, Validation Accuracy: 0.7500
# Training Precision: 0.8919, Validation Precision: 0.7214
# Training Recall: 0.8969, Validation Recall: 0.7500
# Training F1-Score: 0.8887, Validation F1-Score: 0.7347

# %%
tree_mol_subtype = DecisionTreeClassifier(criterion = 'entropy', max_depth = 5, min_samples_split = 8)
report, tree_mol_subtype = get_classification_report(tree_mol_subtype, train_x, train_y_mol_subtype, val_x, val_y_mol_subtype, test_x, test_y_mol_subtype, ['Luminal', 'ER/PR pos, HER2 pos', 'HER2', 'Triple Negative'], 'Mol Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Decision Tree'
result['Subtype'] = 'Mol Subtype'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.7197, Validation Accuracy: 0.6467
# Training Precision: 0.7338, Validation Precision: 0.5868
# Training Recall: 0.7197, Validation Recall: 0.6467
# Training F1-Score: 0.6569, Validation F1-Score: 0.5574

# %% [markdown]
# ### RandomForest

# %%
forest_er = RandomForestClassifier(n_estimators = 50, criterion = 'gini', max_depth = 6)
report, forest_er = get_classification_report(forest_er, train_x, train_y_er, val_x, val_y_er, test_x, test_y_er, ['ER Negative', 'ER Positive'], 'ER Subtype metrics on testing set')


result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Random Forest'
result['Subtype'] = 'ER'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.8608, Validation Accuracy: 0.7554
# Training Precision: 0.8826, Validation Precision: 0.7343
# Training Recall: 0.8608, Validation Recall: 0.7554
# Training F1-Score: 0.8400, Validation F1-Score: 0.6646

# %%
forest_pr = RandomForestClassifier(n_estimators = 20, criterion = 'gini', max_depth = 15)
report, forest_pr = get_classification_report(forest_pr, train_x, train_y_pr, val_x, val_y_pr, test_x, test_y_pr, ['PR Negative', 'PR Positive'], 'PR Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Random Forest'
result['Subtype'] = 'PR'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.9928, Validation Accuracy: 0.6033
# Training Precision: 0.9928, Validation Precision: 0.5865
# Training Recall: 0.9928, Validation Recall: 0.6033
# Training F1-Score: 0.9928, Validation F1-Score: 0.5919

# %%
forest_her2 = RandomForestClassifier(n_estimators = 50, criterion = 'gini', max_depth = 20)
report, forest_her2 = get_classification_report(forest_her2, train_x, train_y_her, val_x, val_y_her, test_x, test_y_her, ['HER2 Negative', 'HER2 Positive'], 'HER2 Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Random Forest'
result['Subtype'] = 'HER2'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 1.0000, Validation Accuracy: 0.8152
# Training Precision: 1.0000, Validation Precision: 0.6891
# Training Recall: 1.0000, Validation Recall: 0.8152
# Training F1-Score: 1.0000, Validation F1-Score: 0.7469

# %%
forest_mol_subtype = RandomForestClassifier(n_estimators = 50, criterion = 'gini', max_depth = 2)
report, forest_mol_subtype = get_classification_report(forest_mol_subtype, train_x, train_y_mol_subtype, val_x, val_y_mol_subtype, test_x, test_y_mol_subtype, ['Luminal', 'ER/PR pos, HER2 pos', 'HER2', 'Triple Negative'], 'Mol Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'Random Forest'
result['Subtype'] = 'Mol Subtype'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.6510, Validation Accuracy: 0.6630
# Training Precision: 0.4238, Validation Precision: 0.4396
# Training Recall: 0.6510, Validation Recall: 0.6630
# Training F1-Score: 0.5134, Validation F1-Score: 0.5287
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### XGBoost

# %%
xgb_er = xgb.XGBClassifier(n_estimators = 20, max_depth = 10, max_leaves = 20)
report, xgb_er = get_classification_report(xgb_er, train_x, train_y_er, val_x, val_y_er, test_x, test_y_er, ['ER Negative', 'ER Positive'], 'ER Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'XGBoost'
result['Subtype'] = 'ER'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# Training Accuracy: 0.9982, Validation Accuracy: 0.7609
# Training Precision: 0.9982, Validation Precision: 0.7252
# Training Recall: 0.9982, Validation Recall: 0.7609
# Training F1-Score: 0.9982, Validation F1-Score: 0.7095

# %%
xgb_pr = xgb.XGBClassifier(n_estimators = 20, max_leaves = 20)
report, xgb_pr = get_classification_report(xgb_pr, train_x, train_y_pr, val_x, val_y_pr, test_x, test_y_pr, ['PR Negative', 'PR Positive'], 'PR Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'XGBoost'
result['Subtype'] = 'PR'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# Training Accuracy: 0.9982, Validation Accuracy: 0.6033
# Training Precision: 0.9982, Validation Precision: 0.5703
# Training Recall: 0.9982, Validation Recall: 0.6033
# Training F1-Score: 0.9982, Validation F1-Score: 0.5759

# %%
xgb_her2 = xgb.XGBClassifier(n_estimators = 100, max_leaves = 20)
report, nb_pr = get_classification_report(xgb_her2, train_x, train_y_her, val_x, val_y_her, test_x, test_y_her, ['HER2 Negative', 'HER2 Positive'], 'HER2 Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'XGBoost'
result['Subtype'] = 'HER2'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# Training Accuracy: 1.0000, Validation Accuracy: 0.8152
# Training Precision: 1.0000, Validation Precision: 0.7546
# Training Recall: 1.0000, Validation Recall: 0.8152
# Training F1-Score: 1.0000, Validation F1-Score: 0.7706

# %%
xgb_mol_subtype = xgb.XGBClassifier(n_estimators = 100, max_depth = 5)
report, xgb_mol_subtype = get_classification_report(xgb_mol_subtype, train_x, train_y_mol_subtype, val_x, val_y_mol_subtype, test_x, test_y_mol_subtype, ['Luminal', 'ER/PR pos, HER2 pos', 'HER2', 'Triple Negative'], 'Mol Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'XGBoost'
result['Subtype'] = 'Mol Subtype'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# Training Accuracy: 1.0000, Validation Accuracy: 0.6359
# Training Precision: 1.0000, Validation Precision: 0.5022
# Training Recall: 1.0000, Validation Recall: 0.6359
# Training F1-Score: 1.0000, Validation F1-Score: 0.5521

# %% [markdown]
# ### SVM

# %%
svm_er = SVC(C = 1, kernel = 'rbf', degree = 3, gamma = 'auto')
report, svm_er = get_classification_report(svm_er, train_x, train_y_er, val_x, val_y_er, test_x, test_y_er, ['ER Negative', 'ER Positive'], 'ER Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'SVM'
result['Subtype'] = 'ER'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.7486, Validation Accuracy: 0.7500
# Training Precision: 0.5605, Validation Precision: 0.5625
# Training Recall: 0.7486, Validation Recall: 0.7500
# Training F1-Score: 0.6410, Validation F1-Score: 0.6429
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svm_pr = SVC(C = 1, kernel = 'rbf', degree = 3, gamma = 'auto')
report, svm_pr = get_classification_report(svm_pr, train_x, train_y_pr, val_x, val_y_pr, test_x, test_y_pr, ['PR Negative', 'PR Positive'], 'PR Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'SVM'
result['Subtype'] = 'PR'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.6492, Validation Accuracy: 0.6413
# Training Precision: 0.4214, Validation Precision: 0.4113
# Training Recall: 0.6492, Validation Recall: 0.6413
# Training F1-Score: 0.5111, Validation F1-Score: 0.5012
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svm_her2 = SVC(C = 1, kernel = 'rbf', degree = 3, gamma = 'auto')
report, svm_her2 = get_classification_report(svm_pr, train_x, train_y_her, val_x, val_y_her, test_x, test_y_her, ['HER2 Negative', 'HER2 Positive'], 'HER2 Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'SVM'
result['Subtype'] = 'HER2'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.8174, Validation Accuracy: 0.8315
# Training Precision: 0.6681, Validation Precision: 0.6914
# Training Recall: 0.8174, Validation Recall: 0.8315
# Training F1-Score: 0.7352, Validation F1-Score: 0.7550
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svm_mol_subtype = SVC(C = 2, kernel = 'poly', degree = 5, gamma = 'auto')
report, svm_mol_subtype = get_classification_report(svm_mol_subtype, train_x, train_y_mol_subtype, val_x, val_y_mol_subtype, test_x, test_y_mol_subtype, ['Luminal', 'ER/PR pos, HER2 pos', 'HER2', 'Triple Negative'], 'Mol Subtype metrics on testing set')

result = pd.DataFrame(report, index = [0])
result['Algorithm'] = 'SVM'
result['Subtype'] = 'Mol Subtype'
result = result[list(result.columns[-2:]) + list(result.columns[:-2])]
classification_results = pd.concat([classification_results, result])
# Out:
# Training Accuracy: 0.6510, Validation Accuracy: 0.6630
# Training Precision: 0.4238, Validation Precision: 0.4396
# Training Recall: 0.6510, Validation Recall: 0.6630
# Training F1-Score: 0.5134, Validation F1-Score: 0.5287
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\ProgramData\Anaconda3\envs\torchnew\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Classification scores

# %%
classification_results.reset_index(drop = True, inplace = True)
classification_results.sort_values(by = ['Subtype', 'Algorithm'])
# Out:
#               Algorithm      Subtype  train_acc   val_acc  train_prec  \
# 8         Decision Tree           ER   0.773960  0.722826    0.762621
# 4   Logistic Regression           ER   0.761302  0.755435    0.743978
# 0           Naive Bayes           ER   0.712477  0.733696    0.679733
# 12        Random Forest           ER   0.860759  0.755435    0.882596
# 20                  SVM           ER   0.748644  0.750000    0.560467
# 16              XGBoost           ER   0.998192  0.760870    0.998196
# 10        Decision Tree         HER2   0.896926  0.750000    0.891932
# 6   Logistic Regression         HER2   0.817360  0.820652    0.761287
# 3           Naive Bayes         HER2   0.688969  0.717391    0.717563
# 14        Random Forest         HER2   1.000000  0.815217    1.000000
# 22                  SVM         HER2   0.817360  0.831522    0.668077
# 18              XGBoost         HER2   1.000000  0.815217    1.000000
# 11        Decision Tree  Mol Subtype   0.719711  0.646739    0.733793
# 7   Logistic Regression  Mol Subtype   0.658228  0.657609    0.548616
# 2           Naive Bayes  Mol Subtype   0.358047  0.353261    0.590729
# 15        Random Forest  Mol Subtype   0.650995  0.663043    0.423794
# 23                  SVM  Mol Subtype   0.650995  0.663043    0.423794
# 19              XGBoost  Mol Subtype   1.000000  0.635870    1.000000
# 9         Decision Tree           PR   0.735986  0.614130    0.735371
# 5   Logistic Regression           PR   0.663653  0.646739    0.638045
# 1           Naive Bayes           PR   0.638336  0.646739    0.603406
# 13        Random Forest           PR   0.992767  0.603261    0.992778
# 21                  SVM           PR   0.649186  0.641304    0.421443
# 17              XGBoost           PR   0.998192  0.603261    0.998197
#
#     val_prec  train_rec   val_rec  train_f1    val_f1  test_acc  test_prec  \
# 8   0.616984   0.773960  0.722826  0.716174  0.645977  0.697297   0.583927
# 4   0.719832   0.761302  0.755435  0.685765  0.672945  0.702703   0.567945
# 0   0.694906   0.712477  0.733696  0.690949  0.703727  0.632432   0.586247
# 12  0.734346   0.860759  0.755435  0.840013  0.664609  0.713514   0.631276
# 20  0.562500   0.748644  0.750000  0.641031  0.642857  0.724324   0.524646
# 16  0.725210   0.998192  0.760870  0.998190  0.709524  0.708108   0.652772
# 10  0.721375   0.896926  0.750000  0.888677  0.734666  0.724324   0.705175
# 6   0.689889   0.817360  0.820652  0.741847  0.749611  0.832432   0.779752
# 3   0.744239   0.688969  0.717391  0.702098  0.729747  0.718919   0.770203
# 14  0.689106   1.000000  0.815217  1.000000  0.746876  0.827027   0.751074
# 22  0.691428   0.817360  0.831522  0.735217  0.755032  0.832432   0.692944
# 18  0.754638   1.000000  0.815217  1.000000  0.770599  0.816216   0.727207
# 11  0.586806   0.719711  0.646739  0.656937  0.557351  0.567568   0.479190
# 7   0.528738   0.658228  0.657609  0.540444  0.538883  0.616216   0.505888
# 2   0.643003   0.358047  0.353261  0.400832  0.415567  0.275676   0.445708
# 15  0.439627   0.650995  0.663043  0.513380  0.528701  0.610811   0.373090
# 23  0.439627   0.650995  0.663043  0.513380  0.528701  0.610811   0.373090
# 19  0.502221   1.000000  0.635870  1.000000  0.552070  0.578378   0.431529
# 9   0.607825   0.735986  0.614130  0.735668  0.610537  0.605405   0.606861
# 5   0.612516   0.663653  0.646739  0.597933  0.566915  0.654054   0.614359
# 1   0.614888   0.638336  0.646739  0.601453  0.597718  0.589189   0.549599
# 13  0.586460   0.992767  0.603261  0.992758  0.591947  0.643243   0.630895
# 21  0.411271   0.649186  0.641304  0.511092  0.501152  0.654054   0.427787
# 17  0.570284   0.998192  0.603261  0.998191  0.575914  0.627027   0.604826
#
#     test_rec   test_f1  test_aucroc
# 8   0.697297  0.611857     0.516754
# 4   0.702703  0.606720     0.570530
# 0   0.632432  0.604617     0.530875
# 12  0.713514  0.628921     0.574773
# 20  0.724324  0.608523          NaN
# 16  0.708108  0.656958     0.562628
# 10  0.724324  0.714435     0.469837
# 6   0.832432  0.766014     0.563259
# 3   0.718919  0.740047     0.593842
# 14  0.827027  0.763010     0.525241
# 22  0.832432  0.756310          NaN
# 18  0.816216  0.757003     0.546502
# 11  0.567568  0.478624          NaN
# 7   0.616216  0.485281          NaN
# 2   0.275676  0.310094          NaN
# 15  0.610811  0.463232          NaN
# 23  0.610811  0.463232          NaN
# 19  0.578378  0.478370          NaN
# 9   0.605405  0.606116     0.543776
# 5   0.654054  0.595159     0.581870
# 1   0.589189  0.560321     0.526795
# 13  0.643243  0.635205     0.598980
# 21  0.654054  0.517258          NaN
# 17  0.627027  0.610706     0.561983

# %%
classification_results.to_csv("Classification results/With feature scaling results.csv", index = False)
