# %%
# %pip install pyradiomics dicom_numpy pydicom plotly matplotlib scikit-image simpleITK pynrrd dicom2nifti NiBabel NiLearn openpyxl pydicom-seg
# Out:
# Requirement already satisfied: pyradiomics in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (3.1.0)
# Requirement already satisfied: dicom_numpy in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.6.5)
# Requirement already satisfied: pydicom in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (2.4.1)
# Requirement already satisfied: plotly in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (5.15.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (3.5.3)
# Requirement already satisfied: scikit-image in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.19.3)
# Requirement already satisfied: simpleITK in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (2.2.1)
# Requirement already satisfied: pynrrd in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (1.0.0)
# Requirement already satisfied: dicom2nifti in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (2.4.8)
# Requirement already satisfied: NiBabel in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (4.0.2)
# Requirement already satisfied: NiLearn in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.10.1)
# Requirement already satisfied: openpyxl in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (3.1.2)
# Requirement already satisfied: pydicom-seg in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.4.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.16.0)
# Requirement already satisfied: pykwalify in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.8.0)
# Requirement already satisfied: PyWavelets in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.3.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.21.5)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from plotly) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: imageio>=2.4.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (2.31.1)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (2021.11.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (1.7.3)
# Requirement already satisfied: networkx>=2.2 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pynrrd) (4.6.3)
# Requirement already satisfied: nptyping in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pynrrd) (2.5.0)
# Requirement already satisfied: python-gdcm in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from dicom2nifti) (3.0.22)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiBabel) (65.6.3)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (4.9.3)
# Requirement already satisfied: joblib>=1.0.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (1.3.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (1.0.2)
# Requirement already satisfied: requests>=2.25.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (2.31.0)
# Requirement already satisfied: pandas>=1.1.5 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (1.3.5)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: jsonschema<4.0.0,>=3.2.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pydicom-seg) (3.2.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (6.7.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (23.1.0)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pandas>=1.1.5->NiLearn) (2023.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (2.0.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (2023.5.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-learn>=1.0.0->NiLearn) (3.1.0)
# Requirement already satisfied: ruamel.yaml>=0.16.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pykwalify->pyradiomics) (0.17.32)
# Requirement already satisfied: docopt>=0.6.2 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pykwalify->pyradiomics) (0.6.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from ruamel.yaml>=0.16.0->pykwalify->pyradiomics) (0.2.7)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from importlib-metadata->jsonschema<4.0.0,>=3.2.0->pydicom-seg) (3.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import dicom_numpy
import pydicom as dicom

import dicom2nifti
import nibabel as nib
import nilearn as nil
import scipy.ndimage as ndi
import SimpleITK as sitk
import os

from radiomics import featureextractor

from tqdm import tqdm

# %%
metadata = pd.read_csv("../../Dataset/Duke MRI/manifest-1654812109500/metadata.csv")
annotation_boxes = pd.read_excel("../../Dataset/Annotation_Boxes.xlsx").set_index("Patient ID")

DATASET_PATH = '../../New Dataset/'
SEGMENTED_DATASET_PATH = '../../Segmented Dataset/'

# %%
annotation_boxes.loc['Breast_MRI_001']
# Out:
# Start Row       234
# End Row         271
# Start Column    308
# End Column      341
# Start Slice      89
# End Slice       112
# Name: Breast_MRI_001, dtype: int64

# %%
feat_ext = featureextractor.RadiomicsFeatureExtractor()
feat_ext.settings['minimumROIDimensions'] = 2
feat_ext.settings['normalize'] = True
feat_ext.settings['additionalInfo'] = False
feat_ext.settings
# Out:
# {'minimumROIDimensions': 2,
#  'minimumROISize': None,
#  'normalize': True,
#  'normalizeScale': 1,
#  'removeOutliers': None,
#  'resampledPixelSpacing': None,
#  'interpolator': 'sitkBSpline',
#  'preCrop': False,
#  'padDistance': 5,
#  'distances': [1],
#  'force2D': False,
#  'force2Ddimension': 0,
#  'resegmentRange': None,
#  'label': 1,
#  'additionalInfo': False}

# %%
feats = feat_ext.execute('../../New Dataset/Breast_MRI_001/11_ax_dyn_3rd_pass.nii.gz', '../../New Dataset/Breast_MRI_001/segment.nii.gz')
# Out:
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated

# %%
for key, value in feats.items():
    feats[key] = value.item()

# %%
pd.DataFrame(feats, index = [1])
# Out:
#    original_shape_Elongation  original_shape_Flatness  \
# 1                   0.891808                 0.850437
#
#    original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 1                       29.186299                       34.319179
#
#    original_shape_Maximum2DDiameterColumn  \
# 1                               38.431136
#
#    original_shape_Maximum2DDiameterRow  original_shape_Maximum2DDiameterSlice  \
# 1                            36.073737                              39.309346
#
#    original_shape_Maximum3DDiameter  original_shape_MeshVolume  \
# 1                         46.240422               19914.791496
#
#    original_shape_MinorAxisLength  ...  \
# 1                       30.606121  ...
#
#    original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 1                                            2.0
#
#    original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 1                                         0.125                         1.0
#
#    original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 1                       0.000071                 1.971356e+08
#
#    original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 1                 0.591689                   0.845129
#
#    original_ngtdm_Complexity  original_ngtdm_Contrast  original_ngtdm_Strength
# 1                   0.000084             2.768233e-09                 0.916062
#
# [1 rows x 107 columns]

# %%
features = pd.DataFrame()

for patient in tqdm(os.listdir(DATASET_PATH)):
    pat_dir = os.path.join(DATASET_PATH, patient)
    x = annotation_boxes.loc[patient]
    row1 = x['Start Row']
    row2 = x['End Row']

    col1 = x['Start Column']
    col2 = x['End Column']

    slice1 = x['Start Slice']
    slice2 = x['End Slice']
    for nifti_file in os.listdir(pat_dir):
        if(nifti_file == 'segment.nii.gz'):
            continue
        old_file_path = os.path.join(DATASET_PATH, patient)

        nifti_path = os.path.join(old_file_path, nifti_file)
        segment_path = os.path.join(old_file_path, 'segment.nii.gz')

        nifti_img = nib.load(nifti_path)
        mask = np.zeros(nifti_img.dataobj.shape)
        mask[row1:row2, col1:col2, slice1:slice2] = 1
        new_img = nib.Nifti1Image(mask, affine = nifti_img.affine)
        nib.save(new_img, segment_path)

        # feature extraction
        feats = feat_ext.execute(nifti_path, segment_path)
        for key, value in feats.items():
            feats[key] = value.item()

        ft_df = pd.DataFrame(feats, index = [0])
        ft_df['patient'] = patient
        ft_df['sequence'] = nifti_file
        features = pd.concat([features, ft_df])
# Out:
#   0%|          | 0/922 [00:00<?, ?it/s]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 1/922 [00:01<23:52,  1.56s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 2/922 [00:03<25:28,  1.66s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 3/922 [00:05<27:50,  1.82s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 4/922 [00:07<28:26,  1.86s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#
/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  89%|████████▊ | 817/922 [30:51<03:59,  2.28s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  89%|████████▊ | 818/922 [30:53<03:43,  2.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  89%|████████▉ | 819/922 [30:55<03:17,  1.91s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  89%|████████▉ | 820/922 [31:01<05:22,  3.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  89%|████████▉ | 821/922 [31:02<04:37,  2.74s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  89%|████████▉ | 822/922 [31:05<04:19,  2.59s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  89%|████████▉ | 823/922 [31:07<03:56,  2.39s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  89%|████████▉ | 824/922 [31:08<03:28,  2.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  89%|████████▉ | 825/922 [31:10<03:31,  2.18s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|████████▉ | 826/922 [31:12<03:23,  2.12s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|████████▉ | 827/922 [31:14<03:15,  2.05s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|████████▉ | 828/922 [31:17<03:20,  2.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|████████▉ | 829/922 [31:18<03:11,  2.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|█████████ | 830/922 [31:20<02:58,  1.94s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|█████████ | 831/922 [31:24<03:54,  2.58s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|█████████ | 832/922 [31:26<03:34,  2.39s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|█████████ | 833/922 [31:28<03:19,  2.25s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  90%|█████████ | 834/922 [31:30<03:07,  2.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  91%|█████████ | 835/922 [31:32<03:01,  2.09s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  91%|█████████ | 836/922 [31:34<02:47,  1.94s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  91%|█████████ | 837/922 [31:36<02:54,  2.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  91%|█████████ | 838/922 [31:38<02:47,  1.99s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  91%|█████████ | 839/922 [31:40<02:56,  2.12s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  91%|█████████ | 840/922 [31:42<02:56,  2.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  91%|█████████ | 841/922 [31:44<02:49,  2.09s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  91%|█████████▏| 842/922 [31:47<02:52,  2.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  91%|█████████▏| 843/922 [31:49<02:47,  2.11s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▏| 844/922 [31:50<02:37,  2.02s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▏| 845/922 [31:52<02:32,  1.98s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▏| 846/922 [31:55<02:40,  2.11s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▏| 847/922 [31:56<02:24,  1.92s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▏| 848/922 [32:00<03:13,  2.62s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▏| 849/922 [32:02<02:48,  2.31s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▏| 850/922 [32:04<02:48,  2.35s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▏| 851/922 [32:06<02:30,  2.12s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  92%|█████████▏| 852/922 [32:08<02:27,  2.11s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 853/922 [32:10<02:28,  2.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 854/922 [32:12<02:19,  2.05s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 855/922 [32:14<02:16,  2.03s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 856/922 [32:16<02:17,  2.08s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 857/922 [32:19<02:34,  2.38s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 858/922 [32:21<02:23,  2.24s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 859/922 [32:24<02:23,  2.28s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 860/922 [32:26<02:14,  2.18s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 861/922 [32:28<02:18,  2.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 862/922 [32:30<02:11,  2.19s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▎| 863/922 [32:32<01:57,  1.99s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▎| 864/922 [32:33<01:50,  1.90s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 865/922 [32:35<01:48,  1.90s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 866/922 [32:36<01:27,  1.56s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 867/922 [32:39<01:42,  1.86s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 868/922 [32:41<01:48,  2.00s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 869/922 [32:43<01:53,  2.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 870/922 [32:46<01:53,  2.19s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 871/922 [32:48<01:54,  2.24s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 872/922 [32:50<01:51,  2.24s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 873/922 [32:53<01:54,  2.34s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 874/922 [33:03<03:39,  4.57s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 875/922 [33:05<02:59,  3.82s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 876/922 [33:06<02:20,  3.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 877/922 [33:08<02:07,  2.83s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 878/922 [33:11<01:57,  2.67s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 879/922 [33:15<02:17,  3.20s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 880/922 [33:17<01:58,  2.83s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 881/922 [33:18<01:34,  2.30s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 882/922 [33:20<01:29,  2.24s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 883/922 [33:22<01:19,  2.03s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 884/922 [33:24<01:15,  2.00s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 885/922 [33:25<01:11,  1.94s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 886/922 [33:27<01:09,  1.94s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 887/922 [33:30<01:14,  2.14s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▋| 888/922 [33:32<01:13,  2.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▋| 889/922 [33:34<01:07,  2.03s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 890/922 [33:35<00:57,  1.81s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 891/922 [33:37<00:56,  1.82s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 892/922 [33:39<00:54,  1.80s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 893/922 [33:40<00:49,  1.69s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 894/922 [33:42<00:49,  1.77s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 895/922 [33:44<00:48,  1.79s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 896/922 [33:46<00:50,  1.93s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 897/922 [33:48<00:48,  1.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 898/922 [33:51<00:49,  2.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 899/922 [33:53<00:51,  2.25s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 900/922 [33:55<00:45,  2.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 901/922 [33:57<00:42,  2.01s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 902/922 [33:59<00:40,  2.02s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 903/922 [34:01<00:37,  1.97s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 904/922 [34:02<00:32,  1.79s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 905/922 [34:04<00:30,  1.80s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 906/922 [34:05<00:26,  1.67s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 907/922 [34:08<00:28,  1.88s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 908/922 [34:09<00:24,  1.77s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▊| 909/922 [34:11<00:24,  1.85s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▊| 910/922 [34:14<00:24,  2.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 911/922 [34:16<00:24,  2.19s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 912/922 [34:19<00:22,  2.26s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 913/922 [34:20<00:18,  2.08s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 914/922 [34:23<00:17,  2.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 915/922 [34:25<00:15,  2.25s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 916/922 [34:27<00:12,  2.14s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 917/922 [34:33<00:17,  3.44s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 918/922 [34:36<00:12,  3.23s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 919/922 [34:39<00:09,  3.02s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 920/922 [34:40<00:05,  2.57s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 921/922 [34:42<00:02,  2.44s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|██████████| 922/922 [34:44<00:00,  2.26s/it]

# %%
features.to_csv("pyradiomics_extraction.csv", index = False)
