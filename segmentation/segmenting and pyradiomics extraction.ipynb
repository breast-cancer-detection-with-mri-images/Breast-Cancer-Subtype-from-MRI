# %%
# %pip install pyradiomics dicom_numpy pydicom plotly matplotlib scikit-image simpleITK pynrrd dicom2nifti NiBabel NiLearn openpyxl pydicom-seg
# Out:
# Requirement already satisfied: pyradiomics in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (3.1.0)
# Requirement already satisfied: dicom_numpy in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.6.5)
# Requirement already satisfied: pydicom in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (2.4.1)
# Requirement already satisfied: plotly in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (5.15.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (3.5.3)
# Requirement already satisfied: scikit-image in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.19.3)
# Requirement already satisfied: simpleITK in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (2.2.1)
# Requirement already satisfied: pynrrd in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (1.0.0)
# Requirement already satisfied: dicom2nifti in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (2.4.8)
# Requirement already satisfied: NiBabel in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (4.0.2)
# Requirement already satisfied: NiLearn in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.10.1)
# Requirement already satisfied: openpyxl in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (3.1.2)
# Requirement already satisfied: pydicom-seg in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.4.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.3.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.21.5)
# Requirement already satisfied: pykwalify in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.8.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from plotly) (23.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: networkx>=2.2 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: imageio>=2.4.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (2.31.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (1.7.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (2021.11.2)
# Requirement already satisfied: nptyping in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pynrrd) (2.5.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pynrrd) (4.6.3)
# Requirement already satisfied: python-gdcm in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from dicom2nifti) (3.0.22)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiBabel) (65.6.3)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (4.9.3)
# Requirement already satisfied: joblib>=1.0.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (1.3.1)
# Requirement already satisfied: requests>=2.25.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (2.31.0)
# Requirement already satisfied: pandas>=1.1.5 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (1.3.5)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (1.0.2)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: jsonschema<4.0.0,>=3.2.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pydicom-seg) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (23.1.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (6.7.0)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pandas>=1.1.5->NiLearn) (2023.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (2.0.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (3.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-learn>=1.0.0->NiLearn) (3.1.0)
# Requirement already satisfied: ruamel.yaml>=0.16.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pykwalify->pyradiomics) (0.17.32)
# Requirement already satisfied: docopt>=0.6.2 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pykwalify->pyradiomics) (0.6.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from ruamel.yaml>=0.16.0->pykwalify->pyradiomics) (0.2.7)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from importlib-metadata->jsonschema<4.0.0,>=3.2.0->pydicom-seg) (3.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import dicom_numpy
import pydicom as dicom

import dicom2nifti
import nibabel as nib
import nilearn as nil
import scipy.ndimage as ndi
import SimpleITK as sitk
import os

from radiomics import featureextractor

from tqdm import tqdm
# Out:
# c:\ProgramData\Anaconda3\envs\mri_project\lib\site-packages\nilearn\__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()

# %%
annotation_boxes = pd.read_excel("../../Simple Path Dataset/Annotation_Boxes.xlsx").set_index("Patient ID")

DATASET_PATH = '../../New Dataset/'
# SEGMENTED_DATASET_PATH = '../../Segmented Dataset/'

# %%
annotation_boxes
# Out:
#                 Start Row  End Row  Start Column  End Column  Start Slice  \
# Patient ID
# Breast_MRI_001        234      271           308         341           89
# Breast_MRI_002        251      294           108         136           59
# Breast_MRI_003        351      412            82         139           96
# Breast_MRI_004        262      280           193         204           86
# Breast_MRI_005        188      213           138         178           76
# ...                   ...      ...           ...         ...          ...
# Breast_MRI_918        345      395           338         395           62
# Breast_MRI_919        285      312           369         397           98
# Breast_MRI_920        172      193           337         355           87
# Breast_MRI_921        328      374           404         446           97
# Breast_MRI_922        258      270           149         164           82
#
#                 End Slice
# Patient ID
# Breast_MRI_001        112
# Breast_MRI_002         72
# Breast_MRI_003        108
# Breast_MRI_004         95
# Breast_MRI_005        122
# ...                   ...
# Breast_MRI_918         85
# Breast_MRI_919        109
# Breast_MRI_920        101
# Breast_MRI_921        121
# Breast_MRI_922         92
#
# [922 rows x 6 columns]

# %%
annotation_boxes.loc['Breast_MRI_001']
# Out:
# Start Row       234
# End Row         271
# Start Column    308
# End Column      341
# Start Slice      89
# End Slice       112
# Name: Breast_MRI_001, dtype: int64

# %%
filenames = ['pre.nii.gz', 'post_1.nii.gz']

# %%
# generate segmentation masks for each patient in the directory

for item in tqdm(os.listdir(DATASET_PATH)):
    patient_path = os.path.join(DATASET_PATH, item)

    x = annotation_boxes.loc[item]
    row1 = x['Start Row']
    row2 = x['End Row']

    col1 = x['Start Column']
    col2 = x['End Column']

    slice1 = x['Start Slice']
    slice2 = x['End Slice']

    if(os.path.isdir(patient_path)):
        # find files with paths here
        nifti_img = nib.load(os.path.join(patient_path, filenames[0]))   #load pre path and generate segments from this
        mask = np.zeros(nifti_img.dataobj.shape)
        mask[row1:row2, col1:col2, slice1:slice2] = 1
        segment = nib.Nifti1Image(mask, affine = nifti_img.affine)
        nib.save(segment, os.path.join(patient_path, 'segmentation.nii.gz'))
# Out:
# 100%|██████████| 922/922 [15:48<00:00,  1.03s/it]

# %%
feat_ext = featureextractor.RadiomicsFeatureExtractor()
feat_ext.settings['minimumROIDimensions'] = 2
feat_ext.settings['normalize'] = True
feat_ext.settings['additionalInfo'] = False
feat_ext.settings
# Out:
# {'minimumROIDimensions': 2,
#  'minimumROISize': None,
#  'normalize': True,
#  'normalizeScale': 1,
#  'removeOutliers': None,
#  'resampledPixelSpacing': None,
#  'interpolator': 'sitkBSpline',
#  'preCrop': False,
#  'padDistance': 5,
#  'distances': [1],
#  'force2D': False,
#  'force2Ddimension': 0,
#  'resegmentRange': None,
#  'label': 1,
#  'additionalInfo': False}

# %%
features = pd.DataFrame()

for patient in tqdm(os.listdir(DATASET_PATH)):
    segmentation_path = os.path.join(DATASET_PATH, patient, 'segmentation.nii.gz')
    for filename in filenames:
        # get features for pre and post_1
        file_path = os.path.join(DATASET_PATH, patient, filename)
        img = sitk.ReadImage(file_path)
        smt = sitk.ReadImage(segmentation_path)

        smt.SetOrigin(img.GetOrigin())
        feats = feat_ext.execute(img, smt)
        for key, value in feats.items():
            feats[key] = value.item()
        ft_df = pd.DataFrame(feats, index = [0])
        ft_df['patient'] = patient
        ft_df['sequence'] = filename.split('.nii.gz')[0]
        features = pd.concat([features, ft_df])
# Out:
#   0%|          | 0/922 [00:00<?, ?it/s]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 1/922 [00:01<29:59,  1.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 2/922 [00:04<31:35,  2.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 3/922 [00:06<34:37,  2.26s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 4/922 [00:08<34:42,  2.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 5/922 [00:10<33:20,  2.18s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 6/922 [00:13<33:06,  2.17s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 7/922 [00:15<33:24,  2.19s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 8/922 [00:17<31:40,  2.08s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 9/922 [00:19<33:18,  2.19s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 10/922 [00:22<35:24,  2.33s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 11/922 [00:25<38:49,  2.56s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|▏         | 12/922 [00:37<1:24:23,  5.56s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|▏         | 13/922 [00:41<1:14:58,  4.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 14/922 [00:43<1:01:16,  4.05s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 15/922 [00:44<49:39,  3.29s/it]  GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 16/922 [00:50<59:21,  3.93s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 17/922 [00:52<50:27,  3.35s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 18/922 [00:54<46:52,  3.11s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 19/922 [00:56<38:53,  2.58s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 20/922 [00:58<38:25,  2.56s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 21/922 [01:01<38:16,  2.55s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 22/922 [01:03<36:15,  2.42s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 23/922 [01:05<35:27,  2.37s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 24/922 [01:08<36:22,  2.43s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 25/922 [01:10<35:53,  2.40s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 26/922 [01:12<35:52,  2.40s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 27/922 [01:14<34:40,  2.32s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 28/922 [01:20<48:44,  3.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 29/922 [01:22<45:39,  3.07s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 30/922 [01:25<43:42,  2.94s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 31/922 [01:27<41:03,  2.76s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 32/922 [01:30<40:28,  2.73s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▎         | 33/922 [01:34<44:50,  3.03s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▎         | 34/922 [01:39<55:43,  3.76s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 35/922 [01:42<51:16,  3.47s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 36/922 [01:44<45:12,  3.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 37/922 [01:45<36:35,  2.48s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 38/922 [01:48<36:05,  2.45s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 39/922 [01:50<33:21,  2.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 40/922 [01:52<34:16,  2.33s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 41/922 [01:55<36:00,  2.45s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▍         | 42/922 [01:58<38:27,  2.62s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▍         | 43/922 [02:01<38:48,  2.65s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▍         | 44/922 [02:02<34:13,  2.34s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#
/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  21%|██▏       | 198/922 [09:43<39:39,  3.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▏       | 199/922 [09:45<37:25,  3.11s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▏       | 200/922 [09:47<33:17,  2.77s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▏       | 201/922 [09:49<30:52,  2.57s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▏       | 202/922 [09:53<34:38,  2.89s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# ...
#  93%|█████████▎| 855/922 [43:25<03:15,  2.92s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 856/922 [43:28<03:06,  2.83s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 857/922 [43:33<03:50,  3.55s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 858/922 [43:36<03:26,  3.23s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 859/922 [43:39<03:27,  3.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 860/922 [43:42<03:13,  3.12s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 861/922 [43:45<03:14,  3.18s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 862/922 [43:48<02:59,  2.99s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▎| 863/922 [43:50<02:44,  2.79s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▎| 864/922 [43:52<02:34,  2.67s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 865/922 [43:55<02:29,  2.62s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 866/922 [43:56<02:04,  2.22s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 867/922 [43:59<02:11,  2.39s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 868/922 [44:02<02:12,  2.46s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 869/922 [44:05<02:28,  2.80s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 870/922 [44:08<02:24,  2.78s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 871/922 [44:11<02:17,  2.71s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 872/922 [44:13<02:13,  2.67s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 873/922 [44:16<02:15,  2.76s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 874/922 [44:34<05:54,  7.39s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 875/922 [44:37<04:40,  5.96s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 876/922 [44:39<03:35,  4.69s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 877/922 [44:41<03:02,  4.06s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 878/922 [44:44<02:44,  3.74s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 879/922 [44:52<03:32,  4.94s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 880/922 [44:54<02:56,  4.21s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 881/922 [44:56<02:19,  3.41s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 882/922 [44:59<02:09,  3.23s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 883/922 [45:01<01:51,  2.86s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 884/922 [45:04<01:48,  2.86s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 885/922 [45:06<01:40,  2.71s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 886/922 [45:08<01:34,  2.63s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 887/922 [45:13<01:46,  3.05s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▋| 888/922 [45:16<01:43,  3.04s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▋| 889/922 [45:18<01:33,  2.84s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 890/922 [45:20<01:21,  2.55s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 891/922 [45:22<01:18,  2.52s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 892/922 [45:24<01:12,  2.43s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 893/922 [45:26<01:06,  2.28s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 894/922 [45:29<01:05,  2.33s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 895/922 [45:31<01:05,  2.42s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 896/922 [45:35<01:09,  2.66s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 897/922 [45:37<01:05,  2.64s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 898/922 [45:40<01:05,  2.74s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 899/922 [45:45<01:15,  3.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 900/922 [45:47<01:05,  2.96s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 901/922 [45:49<00:58,  2.80s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 902/922 [45:52<00:55,  2.76s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 903/922 [45:55<00:51,  2.71s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 904/922 [45:57<00:47,  2.62s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 905/922 [46:00<00:43,  2.57s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 906/922 [46:01<00:37,  2.34s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 907/922 [46:05<00:41,  2.74s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 908/922 [46:07<00:35,  2.55s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▊| 909/922 [46:10<00:33,  2.56s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▊| 910/922 [46:13<00:34,  2.87s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 911/922 [46:16<00:32,  2.96s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 912/922 [46:19<00:29,  2.94s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 913/922 [46:22<00:24,  2.76s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 914/922 [46:25<00:22,  2.87s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 915/922 [46:29<00:22,  3.18s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 916/922 [46:31<00:17,  3.00s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 917/922 [46:43<00:28,  5.75s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 918/922 [46:47<00:20,  5.10s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 919/922 [46:50<00:13,  4.52s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 920/922 [46:52<00:07,  3.78s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 921/922 [46:55<00:03,  3.60s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|██████████| 922/922 [46:58<00:00,  3.06s/it]

# %%
features.to_csv("pyradiomics_extraction.csv", index = False)

# %%
# Out:
#     original_shape_Elongation  original_shape_Flatness  \
# 0                    0.891808                 0.850437
# 0                    0.891808                 0.850437
# 0                    0.668996                 0.650923
# 0                    0.668996                 0.650923
# 0                    0.934408                 0.286810
# ..                        ...                      ...
# 0                    0.877183                 0.856791
# 0                    0.913000                 0.800835
# 0                    0.913000                 0.800835
# 0                    0.945533                 0.798995
# 0                    0.945533                 0.798995
#
#     original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        29.186299                       34.319179
# 0                        29.186299                       34.319179
# 0                        18.931009                       29.083312
# 0                        18.931009                       29.083312
# 0                        13.808210                       48.144081
# ..                             ...                             ...
# 0                        15.749673                       18.382163
# 0                        33.226543                       41.489900
# 0                        33.226543                       41.489900
# 0                         9.708553                       12.150957
# 0                         9.708553                       12.150957
#
#     original_shape_Maximum2DDiameterColumn  \
# 0                                38.431136
# 0                                38.431136
# 0                                29.852205
# 0                                29.852205
# 0                                43.126056
# ..                                     ...
# 0                                20.649190
# 0                                45.448460
# 0                                45.448460
# 0                                12.641847
# 0                                12.641847
#
#     original_shape_Maximum2DDiameterRow  \
# 0                             36.073737
# 0                             36.073737
# 0                             23.148662
# 0                             23.148662
# 0                             40.488107
# ..                                  ...
# 0                             19.038279
# 0                             43.076382
# 0                             43.076382
# 0                             14.031840
# 0                             14.031840
#
#     original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 0                               39.309346                         46.240422
# 0                               39.309346                         46.240422
# 0                               29.748492                         33.784677
# 0                               29.748492                         33.784677
# 0                               56.606869                         57.665740
# ..                                    ...                               ...
# 0                               20.505122                         24.348411
# 0                               48.143552                         55.603011
# 0                               48.143552                         55.603011
# 0                               13.078416                         16.022136
# 0                               13.078416                         16.022136
#
#     original_shape_MeshVolume  original_shape_MinorAxisLength  ...  \
# 0                19914.791496                       30.606121  ...
# 0                19914.791496                       30.606121  ...
# 0                 6966.458183                       19.456628  ...
# 0                 6966.458183                       19.456628  ...
# 0                19467.935987                       44.986213  ...
# ..                        ...                             ...  ...
# 0                 3033.167788                       16.124515  ...
# 0                33924.801358                       37.880295  ...
# 0                33924.801358                       37.880295  ...
# 0                  881.013461                       11.489125  ...
# 0                  881.013461                       11.489125  ...
#
#     original_glszm_ZoneEntropy  original_glszm_ZonePercentage  \
# 0                 1.750000e+00                       0.000285
# 0                -3.203427e-16                       0.000036
# 0                 2.978075e+00                       0.005367
# 0                 1.943752e+00                       0.001278
# 0                 2.846439e+00                       0.000240
# ..                         ...                            ...
# 0                -3.203427e-16                       0.000189
# 0                 1.971225e+00                       0.002027
# 0                 2.541725e+00                       0.001294
# 0                 2.753434e+00                       0.007778
# 0                 1.842371e+00                       0.003889
#
#     original_glszm_ZoneVariance  original_ngtdm_Busyness  \
# 0                  8.618192e+07                 5.497338
# 0                  0.000000e+00                 0.000000
# 0                  2.374784e+06               288.409155
# 0                  1.153687e+07                13.650935
# 0                  1.041128e+08              1140.457544
# ..                          ...                      ...
# 0                  0.000000e+00                 0.000000
# 0                  1.360858e+07              6049.519483
# 0                  2.233828e+07              2876.276646
# 0                  1.507122e+05                73.646825
# 0                  2.742273e+05                70.211339
#
#     original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# 0                    0.091060                   0.000782
# 0              1000000.000000                   0.000000
# 0                    0.001006                   0.127011
# 0                    0.018427                   0.006934
# 0                    0.000980                   0.048920
# ..                        ...                        ...
# 0              1000000.000000                   0.000000
# 0                    0.000420                   0.102645
# 0                    0.000583                   0.073943
# 0                    0.004476                   0.248217
# 0                    0.004649                   0.238979
#
#     original_ngtdm_Contrast  original_ngtdm_Strength         patient  sequence
# 0              3.011166e-07                 0.092604  Breast_MRI_001       pre
# 0              0.000000e+00                 0.000000  Breast_MRI_001    post_1
# 0              1.063641e-02                 0.001006  Breast_MRI_002       pre
# 0              2.849699e-05                 0.018260  Breast_MRI_002    post_1
# 0              7.407411e-03                 0.000972  Breast_MRI_003       pre
# ..                      ...                      ...             ...       ...
# 0              0.000000e+00                 0.000000  Breast_MRI_920    post_1
# 0              2.014567e-02                 0.000420  Breast_MRI_921       pre
# 0              1.326310e-02                 0.000583  Breast_MRI_921    post_1
# 0              3.370219e-02                 0.004456  Breast_MRI_922       pre
# 0              3.147907e-02                 0.004650  Breast_MRI_922    post_1
#
# [1844 rows x 109 columns]
