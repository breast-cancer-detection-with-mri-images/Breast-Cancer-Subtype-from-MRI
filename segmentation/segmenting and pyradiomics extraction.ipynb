# %%
# %pip install pyradiomics dicom_numpy pydicom plotly matplotlib scikit-image simpleITK pynrrd dicom2nifti NiBabel NiLearn openpyxl pydicom-seg
# Out:
# Requirement already satisfied: pyradiomics in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (3.1.0)
# Requirement already satisfied: dicom_numpy in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.6.5)
# Requirement already satisfied: pydicom in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (2.4.1)
# Requirement already satisfied: plotly in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (5.15.0)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (3.5.3)
# Requirement already satisfied: scikit-image in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.19.3)
# Requirement already satisfied: simpleITK in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (2.2.1)
# Requirement already satisfied: pynrrd in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (1.0.0)
# Requirement already satisfied: dicom2nifti in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (2.4.8)
# Requirement already satisfied: NiBabel in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (4.0.2)
# Requirement already satisfied: NiLearn in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.10.1)
# Requirement already satisfied: openpyxl in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (3.1.2)
# Requirement already satisfied: pydicom-seg in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (0.4.1)
# Requirement already satisfied: six in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.3.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.21.5)
# Requirement already satisfied: pykwalify in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pyradiomics) (1.8.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from plotly) (23.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: networkx>=2.2 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (2.6.3)
# Requirement already satisfied: imageio>=2.4.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (2.31.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (1.7.3)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-image) (2021.11.2)
# Requirement already satisfied: nptyping in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pynrrd) (2.5.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pynrrd) (4.6.3)
# Requirement already satisfied: python-gdcm in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from dicom2nifti) (3.0.22)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiBabel) (65.6.3)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (4.9.3)
# Requirement already satisfied: joblib>=1.0.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (1.3.1)
# Requirement already satisfied: requests>=2.25.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (2.31.0)
# Requirement already satisfied: pandas>=1.1.5 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (1.3.5)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from NiLearn) (1.0.2)
# Requirement already satisfied: et-xmlfile in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: jsonschema<4.0.0,>=3.2.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pydicom-seg) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (23.1.0)
# Requirement already satisfied: importlib-metadata in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg) (6.7.0)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pandas>=1.1.5->NiLearn) (2023.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (2.0.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from requests>=2.25.0->NiLearn) (3.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from scikit-learn>=1.0.0->NiLearn) (3.1.0)
# Requirement already satisfied: ruamel.yaml>=0.16.0 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pykwalify->pyradiomics) (0.17.32)
# Requirement already satisfied: docopt>=0.6.2 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from pykwalify->pyradiomics) (0.6.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from ruamel.yaml>=0.16.0->pykwalify->pyradiomics) (0.2.7)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\envs\mri_project\lib\site-packages (from importlib-metadata->jsonschema<4.0.0,>=3.2.0->pydicom-seg) (3.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import dicom_numpy
import pydicom as dicom

import dicom2nifti
import nibabel as nib
import nilearn as nil
import scipy.ndimage as ndi
import SimpleITK as sitk
import os

from radiomics import featureextractor

from tqdm import tqdm
# Out:
# c:\ProgramData\Anaconda3\envs\mri_project\lib\site-packages\nilearn\__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()

# %%
annotation_boxes = pd.read_csv("segmentation_annotations_NIFTI.csv").set_index("Patient_ID")

DATASET_PATH = '../../New Dataset/'
# SEGMENTED_DATASET_PATH = '../../Segmented Dataset/'

# %%
annotation_boxes
# Out:
#                 Start Row  End Row  Start Column  End Column  Start Slice  \
# Patient_ID
# Breast_MRI_001        308      341           234         271           48
# Breast_MRI_002        108      136           251         294           70
# Breast_MRI_003         82      139           351         412           48
# Breast_MRI_004        193      204           262         280           69
# Breast_MRI_005        138      178           188         213           38
# ...                   ...      ...           ...         ...          ...
# Breast_MRI_918        338      395           345         395          107
# Breast_MRI_919        369      397           285         312           83
# Breast_MRI_920        337      355           172         193           59
# Breast_MRI_921        404      446           328         374           53
# Breast_MRI_922        149      164           258         270           82
#
#                 End Slice
# Patient_ID
# Breast_MRI_001         71
# Breast_MRI_002         83
# Breast_MRI_003         60
# Breast_MRI_004         78
# Breast_MRI_005         84
# ...                   ...
# Breast_MRI_918        130
# Breast_MRI_919         94
# Breast_MRI_920         73
# Breast_MRI_921         77
# Breast_MRI_922         92
#
# [922 rows x 6 columns]

# %%
annotation_boxes.loc['Breast_MRI_001']
# Out:
# Start Row       308
# End Row         341
# Start Column    234
# End Column      271
# Start Slice      48
# End Slice        71
# Name: Breast_MRI_001, dtype: int64

# %%
filenames = ['pre.nii.gz', 'post_1.nii.gz']

# %%
# generate segmentation masks for each patient in the directory

for item in tqdm(os.listdir(DATASET_PATH)):
    patient_path = os.path.join(DATASET_PATH, item)

    x = annotation_boxes.loc[item]
    row1 = x['Start Row']
    row2 = x['End Row']

    col1 = x['Start Column']
    col2 = x['End Column']

    slice1 = x['Start Slice']
    slice2 = x['End Slice']

    if(os.path.isdir(patient_path)):
        # find files with paths here
        nifti_img = nib.load(os.path.join(patient_path, filenames[0]))   #load pre path and generate segments from this
        mask = np.zeros(nifti_img.dataobj.shape)
        mask[row1:row2, col1:col2, slice1:slice2] = 1
        segment = nib.Nifti1Image(mask, affine = nifti_img.affine)
        nib.save(segment, os.path.join(patient_path, 'segmentation.nii.gz'))
# Out:
# 100%|██████████| 922/922 [15:20<00:00,  1.00it/s]

# %%
feat_ext = featureextractor.RadiomicsFeatureExtractor()
feat_ext.settings['minimumROIDimensions'] = 2
feat_ext.settings['normalize'] = True
feat_ext.settings['additionalInfo'] = False
feat_ext.settings
# Out:
# {'minimumROIDimensions': 2,
#  'minimumROISize': None,
#  'normalize': True,
#  'normalizeScale': 1,
#  'removeOutliers': None,
#  'resampledPixelSpacing': None,
#  'interpolator': 'sitkBSpline',
#  'preCrop': False,
#  'padDistance': 5,
#  'distances': [1],
#  'force2D': False,
#  'force2Ddimension': 0,
#  'resegmentRange': None,
#  'label': 1,
#  'additionalInfo': False}

# %%
features = pd.DataFrame()

for patient in tqdm(os.listdir(DATASET_PATH)):
    segmentation_path = os.path.join(DATASET_PATH, patient, 'segmentation.nii.gz')
    for filename in filenames:
        # get features for pre and post_1
        file_path = os.path.join(DATASET_PATH, patient, filename)
        img = sitk.ReadImage(file_path)
        smt = sitk.ReadImage(segmentation_path)

        smt.SetOrigin(img.GetOrigin())
        feats = feat_ext.execute(img, smt)
        for key, value in feats.items():
            feats[key] = value.item()
        ft_df = pd.DataFrame(feats, index = [0])
        ft_df['patient'] = patient
        ft_df['sequence'] = filename.split('.nii.gz')[0]
        features = pd.concat([features, ft_df])
# Out:
#   0%|          | 0/922 [00:00<?, ?it/s]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 1/922 [00:01<29:52,  1.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 2/922 [00:03<30:00,  1.96s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 3/922 [00:06<31:52,  2.08s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   0%|          | 4/922 [00:08<31:54,  2.09s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 5/922 [00:09<29:58,  1.96s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 6/922 [00:11<29:32,  1.94s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 7/922 [00:13<30:02,  1.97s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 8/922 [00:15<28:15,  1.85s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 9/922 [00:17<29:54,  1.97s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 10/922 [00:20<32:22,  2.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|          | 11/922 [00:23<36:58,  2.44s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|▏         | 12/922 [00:35<1:23:47,  5.53s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   1%|▏         | 13/922 [00:39<1:13:37,  4.86s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 14/922 [00:40<59:13,  3.91s/it]  GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 15/922 [00:42<46:47,  3.10s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 16/922 [00:47<57:16,  3.79s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 17/922 [00:49<48:03,  3.19s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 18/922 [00:51<44:29,  2.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 19/922 [00:52<35:55,  2.39s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 20/922 [00:55<35:17,  2.35s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 21/922 [00:57<35:24,  2.36s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 22/922 [00:59<32:50,  2.19s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   2%|▏         | 23/922 [01:01<31:27,  2.10s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 24/922 [01:03<31:59,  2.14s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 25/922 [01:05<31:21,  2.10s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 26/922 [01:07<31:45,  2.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 27/922 [01:09<30:26,  2.04s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 28/922 [01:14<45:10,  3.03s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 29/922 [01:17<41:56,  2.82s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 30/922 [01:19<39:31,  2.66s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 31/922 [01:21<36:25,  2.45s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   3%|▎         | 32/922 [01:23<35:56,  2.42s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▎         | 33/922 [01:27<39:55,  2.70s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▎         | 34/922 [01:32<50:26,  3.41s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 35/922 [01:34<46:17,  3.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 36/922 [01:36<40:36,  2.75s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 37/922 [01:37<31:40,  2.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 38/922 [01:39<31:12,  2.12s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 39/922 [01:40<28:22,  1.93s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 40/922 [01:42<29:24,  2.00s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   4%|▍         | 41/922 [01:45<31:17,  2.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▍         | 42/922 [01:48<33:33,  2.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#   5%|▍         | 43/922 [01:50<34:31,  2.36s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#
/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  21%|██▏       | 197/922 [08:37<38:09,  3.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  21%|██▏       | 198/922 [08:40<35:50,  2.97s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▏       | 199/922 [08:42<33:23,  2.77s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▏       | 200/922 [08:44<29:06,  2.42s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▏       | 201/922 [08:45<26:32,  2.21s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  22%|██▏       | 202/922 [08:49<30:20,  2.53s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# ...
#  93%|█████████▎| 855/922 [39:50<02:37,  2.35s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 856/922 [39:52<02:29,  2.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 857/922 [39:56<03:14,  2.99s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 858/922 [39:58<02:51,  2.68s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 859/922 [40:01<02:42,  2.57s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 860/922 [40:03<02:33,  2.47s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 861/922 [40:06<02:36,  2.57s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  93%|█████████▎| 862/922 [40:08<02:25,  2.42s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▎| 863/922 [40:09<02:11,  2.23s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▎| 864/922 [40:11<02:04,  2.15s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 865/922 [40:13<02:00,  2.12s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 866/922 [40:14<01:38,  1.75s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 867/922 [40:17<01:47,  1.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 868/922 [40:19<01:49,  2.03s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 869/922 [40:22<02:05,  2.36s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 870/922 [40:24<02:02,  2.35s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  94%|█████████▍| 871/922 [40:27<01:56,  2.29s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 872/922 [40:29<01:53,  2.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 873/922 [40:31<01:54,  2.34s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 874/922 [40:49<05:31,  6.91s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▍| 875/922 [40:51<04:17,  5.49s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 876/922 [40:52<03:14,  4.24s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 877/922 [40:55<02:42,  3.62s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 878/922 [40:57<02:24,  3.28s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 879/922 [41:04<03:07,  4.35s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  95%|█████████▌| 880/922 [41:06<02:34,  3.67s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 881/922 [41:07<01:59,  2.91s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 882/922 [41:09<01:49,  2.75s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 883/922 [41:11<01:33,  2.40s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 884/922 [41:13<01:30,  2.38s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 885/922 [41:15<01:22,  2.24s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 886/922 [41:17<01:17,  2.16s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▌| 887/922 [41:21<01:28,  2.54s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▋| 888/922 [41:23<01:24,  2.49s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  96%|█████████▋| 889/922 [41:25<01:16,  2.31s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 890/922 [41:26<01:04,  2.02s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 891/922 [41:28<01:02,  2.02s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 892/922 [41:30<00:58,  1.95s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 893/922 [41:32<00:52,  1.81s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 894/922 [41:34<00:52,  1.86s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 895/922 [41:36<00:51,  1.92s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 896/922 [41:38<00:55,  2.13s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 897/922 [41:40<00:52,  2.11s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  97%|█████████▋| 898/922 [41:43<00:52,  2.21s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 899/922 [41:47<01:02,  2.70s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 900/922 [41:48<00:52,  2.39s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 901/922 [41:50<00:47,  2.24s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 902/922 [41:52<00:43,  2.17s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 903/922 [41:54<00:40,  2.12s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 904/922 [41:56<00:36,  2.04s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 905/922 [41:58<00:33,  1.98s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 906/922 [41:59<00:28,  1.77s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 907/922 [42:02<00:32,  2.17s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  98%|█████████▊| 908/922 [42:04<00:27,  1.98s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▊| 909/922 [42:06<00:25,  1.99s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▊| 910/922 [42:09<00:27,  2.27s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 911/922 [42:11<00:26,  2.40s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 912/922 [42:14<00:23,  2.32s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 913/922 [42:15<00:19,  2.14s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 914/922 [42:18<00:18,  2.26s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 915/922 [42:21<00:17,  2.49s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 916/922 [42:23<00:13,  2.32s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
#  99%|█████████▉| 917/922 [42:33<00:23,  4.64s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 918/922 [42:35<00:16,  4.04s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 919/922 [42:38<00:10,  3.53s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 920/922 [42:39<00:05,  2.91s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|█████████▉| 921/922 [42:42<00:02,  2.73s/it]GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# GLCM is symmetrical, therefore Sum Average = 2 * Joint Average, only 1 needs to be calculated
# 100%|██████████| 922/922 [42:44<00:00,  2.78s/it]

# %%
features.to_csv("pyradiomics_extraction.csv", index = False)

# %%
features
# Out:
#     original_shape_Elongation  original_shape_Flatness  \
# 0                    0.891808                 0.850437
# 0                    0.891808                 0.850437
# 0                    0.668996                 0.650923
# 0                    0.668996                 0.650923
# 0                    0.934408                 0.286810
# ..                        ...                      ...
# 0                    0.877183                 0.856791
# 0                    0.913000                 0.800835
# 0                    0.913000                 0.800835
# 0                    0.945533                 0.798995
# 0                    0.945533                 0.798995
#
#     original_shape_LeastAxisLength  original_shape_MajorAxisLength  \
# 0                        29.186299                       34.319179
# 0                        29.186299                       34.319179
# 0                        18.931009                       29.083312
# 0                        18.931009                       29.083312
# 0                        13.808210                       48.144081
# ..                             ...                             ...
# 0                        15.749673                       18.382163
# 0                        33.226543                       41.489900
# 0                        33.226543                       41.489900
# 0                         9.708553                       12.150957
# 0                         9.708553                       12.150957
#
#     original_shape_Maximum2DDiameterColumn  \
# 0                                36.073737
# 0                                36.073737
# 0                                23.148662
# 0                                23.148662
# 0                                40.488107
# ..                                     ...
# 0                                19.038279
# 0                                43.076382
# 0                                43.076382
# 0                                14.031840
# 0                                14.031840
#
#     original_shape_Maximum2DDiameterRow  \
# 0                             38.431136
# 0                             38.431136
# 0                             29.852205
# 0                             29.852205
# 0                             43.126056
# ..                                  ...
# 0                             20.649190
# 0                             45.448460
# 0                             45.448460
# 0                             12.641847
# 0                             12.641847
#
#     original_shape_Maximum2DDiameterSlice  original_shape_Maximum3DDiameter  \
# 0                               39.309346                         46.240422
# 0                               39.309346                         46.240422
# 0                               29.748492                         33.784677
# 0                               29.748492                         33.784677
# 0                               56.606869                         57.665740
# ..                                    ...                               ...
# 0                               20.505122                         24.348411
# 0                               48.143552                         55.603011
# 0                               48.143552                         55.603011
# 0                               13.078416                         16.022136
# 0                               13.078416                         16.022136
#
#     original_shape_MeshVolume  original_shape_MinorAxisLength  ...  \
# 0                19914.791496                       30.606121  ...
# 0                19914.791496                       30.606121  ...
# 0                 6966.458183                       19.456628  ...
# 0                 6966.458183                       19.456628  ...
# 0                19467.935987                       44.986213  ...
# ..                        ...                             ...  ...
# 0                 3033.167788                       16.124515  ...
# 0                33924.801358                       37.880295  ...
# 0                33924.801358                       37.880295  ...
# 0                  881.013461                       11.489125  ...
# 0                  881.013461                       11.489125  ...
#
#     original_glszm_ZoneEntropy  original_glszm_ZonePercentage  \
# 0                     2.825564                       0.003846
# 0                     2.580368                       0.004380
# 0                     3.147323                       0.002108
# 0                     3.339987                       0.003194
# 0                     2.909565                       0.005536
# ..                         ...                            ...
# 0                     1.811278                       0.001512
# 0                     3.258646                       0.001186
# 0                     3.144687                       0.001208
# 0                     1.921928                       0.002778
# 0                     2.521641                       0.003889
#
#     original_glszm_ZoneVariance  original_ngtdm_Busyness  \
# 0                  4.996251e+06              1060.390698
# 0                  4.745944e+06               714.483384
# 0                  5.759789e+06               302.684948
# 0                  4.028316e+06               253.258853
# 0                  6.875739e+06               356.064866
# ..                          ...                      ...
# 0                  3.036683e+06                 4.777973
# 0                  3.581583e+07               258.667361
# 0                  3.514451e+07               259.701406
# 0                  5.076704e+05                 3.463405
# 0                  3.824770e+05                 5.894732
#
#     original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# 0                    0.000323                   0.220287
# 0                    0.000444                   0.160234
# 0                    0.000982                   0.130170
# 0                    0.001130                   0.113070
# 0                    0.000750                   0.063894
# ..                        ...                        ...
# 0                    0.052622                   0.007182
# 0                    0.001018                   0.042386
# 0                    0.001015                   0.042512
# 0                    0.073097                   0.015201
# 0                    0.043424                   0.025588
#
#     original_ngtdm_Contrast  original_ngtdm_Strength         patient  sequence
# 0                  0.032468                 0.000324  Breast_MRI_001       pre
# 0                  0.019571                 0.000443  Breast_MRI_001    post_1
# 0                  0.012262                 0.000985  Breast_MRI_002       pre
# 0                  0.008739                 0.001129  Breast_MRI_002    post_1
# 0                  0.002623                 0.000748  Breast_MRI_003       pre
# ..                      ...                      ...             ...       ...
# 0                  0.000027                 0.053438  Breast_MRI_920    post_1
# 0                  0.001378                 0.001013  Breast_MRI_921       pre
# 0                  0.001414                 0.001006  Breast_MRI_921    post_1
# 0                  0.000122                 0.075003  Breast_MRI_922       pre
# 0                  0.000405                 0.042007  Breast_MRI_922    post_1
#
# [1844 rows x 109 columns]
