# %%
import pandas as pd
import numpy as np

# %%
segmentation_maskcorrect = pd.read_csv("Results without preprocessing/With feature scaling/pyradiomics_extraction_segmentation_maskcorrect_with_FS.csv")
segmentation_nomaskcorrect = pd.read_csv("Results without preprocessing/With feature scaling/pyradiomics_extraction_segmentation_no_maskcorrect_with_FS.csv")
box_nomaskcorrect = pd.read_csv("Results without preprocessing/With feature scaling/pyradiomics_extraction_box_without_correct_mask_with_FS.csv")
box_maskcorrect = pd.read_csv("Results without preprocessing/With feature scaling/pyradiomics_extraction_box_with_correct_mask_with_FS.csv")

# %%
segmentation_maskcorrect
# Out:
#               Algorithm classification  train_acc  train_prec  train_rec  \
# 0           Naive Bayes             ER   0.273056    0.719190   0.273056
# 1         Decision Tree             ER   0.772152    0.753257   0.772152
# 2                   KNN             ER   0.819168    0.808564   0.819168
# 3   Logistic Regression             ER   0.764919    0.753688   0.764919
# 4         Random Forest             ER   0.824593    0.857890   0.824593
# 5                   SVM             ER   0.817360    0.842990   0.817360
# 6               XGBoost             ER   1.000000    1.000000   1.000000
# 7           Naive Bayes             PR   0.365280    0.665492   0.365280
# 8         Decision Tree             PR   0.719711    0.729741   0.719711
# 9                   KNN             PR   0.773960    0.769008   0.773960
# 10  Logistic Regression             PR   0.650995    0.609164   0.650995
# 11        Random Forest             PR   0.846293    0.873465   0.846293
# ...

# %%
segmentation_nomaskcorrect
# Out:
#               Algorithm classification  train_acc  train_prec  train_rec  \
# 0           Naive Bayes             ER   0.273056    0.719190   0.273056
# 1         Decision Tree             ER   0.781193    0.764131   0.781193
# 2                   KNN             ER   0.819168    0.808564   0.819168
# 3   Logistic Regression             ER   0.763110    0.745198   0.763110
# 4         Random Forest             ER   0.830018    0.861471   0.830018
# 5                   SVM             ER   0.817360    0.842990   0.817360
# 6               XGBoost             ER   1.000000    1.000000   1.000000
# 7           Naive Bayes             PR   0.365280    0.665492   0.365280
# 8         Decision Tree             PR   0.681736    0.786436   0.681736
# 9                   KNN             PR   0.773960    0.769008   0.773960
# 10  Logistic Regression             PR   0.650995    0.609164   0.650995
# 11        Random Forest             PR   0.857143    0.875361   0.857143
# ...

# %%
box_maskcorrect
# Out:
#               Algorithm classification  train_acc  train_prec  train_rec  \
# 0           Naive Bayes             ER   0.712477    0.678232   0.712477
# 1         Decision Tree             ER   0.766727    0.822145   0.766727
# 2                   KNN             ER   0.754069    0.712168   0.754069
# 3   Logistic Regression             ER   0.755877    0.754464   0.755877
# 4         Random Forest             ER   0.804702    0.845108   0.804702
# 5                   SVM             ER   0.748644    0.560467   0.748644
# 6               XGBoost             ER   0.994575    0.994614   0.994575
# 7           Naive Bayes             PR   0.641953    0.608347   0.641953
# 8         Decision Tree             PR   0.703436    0.707892   0.703436
# 9                   KNN             PR   0.672694    0.650213   0.672694
# 10  Logistic Regression             PR   0.672694    0.651277   0.672694
# 11        Random Forest             PR   0.974684    0.975634   0.974684
# ...

# %%
box_nomaskcorrect
# Out:
#               Algorithm classification  train_acc  train_prec  train_rec  \
# 0           Naive Bayes             ER   0.712477    0.678232   0.712477
# 1         Decision Tree             ER   0.766727    0.822145   0.766727
# 2                   KNN             ER   0.754069    0.712168   0.754069
# 3   Logistic Regression             ER   0.755877    0.754464   0.755877
# 4         Random Forest             ER   0.799277    0.841715   0.799277
# 5                   SVM             ER   0.748644    0.560467   0.748644
# 6               XGBoost             ER   0.994575    0.994614   0.994575
# 7           Naive Bayes             PR   0.641953    0.608347   0.641953
# 8         Decision Tree             PR   0.701627    0.690085   0.701627
# 9                   KNN             PR   0.672694    0.650213   0.672694
# 10  Logistic Regression             PR   0.672694    0.651277   0.672694
# 11        Random Forest             PR   1.000000    1.000000   1.000000
# ...
