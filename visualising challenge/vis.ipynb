# %%
import pandas as pd
import numpy as np
import os
import glob

import matplotlib.pyplot as plt
import SimpleITK as sitk

# %%
dir = '../../breast-mri-molecular-cancer-subtype/imagesTr/'

# %%
file = os.listdir(dir, )[0]

# %%
img = sitk.ReadImage(os.path.join(dir, file), sitk.sitkInt32)

img = sitk.PatchBasedDenoisingImageFilter().Execute(img)

# %%
plt.imshow(sitk.GetArrayFromImage(img)[90], cmap = 'gray')

# %%
sitk.Show(img)
